# %%
for num in range(1,6):
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for num in range(2,11,2):
    print(num)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
sum=0
for i in range(1,11):
    sum=sum+i
print(sum)
# Out:
# 55

# %%
def factorial(x):
    n=1
    for i in range(1,x+1):
        n*=i
    return n

factorial(5)
# Out:
# 120

# %%
def prime(n):
    if(n<2):
        return false
    if(n==2):
        return true
    for i in range(2, int(n ** 0.5)+1):
        if(n%i==0):
            return false
    return true

# %%
num =7
if prime(num):
    print(f"{num} is prime number")
else:
    print(f"{num} is not prime number")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 num =7
# ----> 2 if prime(num):
#       3     print(f"{num} is prime number")
#       4 else:
#
# Cell In[58], line 9, in prime(n)
#       7     if(n%i==0):
#       8         return false
# ----> 9 return true
#
# NameError: name 'true' is not defined
