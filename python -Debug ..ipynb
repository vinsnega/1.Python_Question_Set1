# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)
 #colon missing

# %%
#1.correct Answer
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)
#Output: Error

# %%
#2.correct code
a=10
b=5
print(a+b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b
#Ans: syntax error: colon missing

# %%
#3.correct code
def add_numbers(a,b):
    return a+b

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])
#Ans:print(numbers[4]),1 placed in [0], 2 placed in position [1], 3 placed in position[2] and 4 placed in position [3] 
# so for numbers[4] doesnt hold any value
#index error out of range
# Out:
#   Cell In[5], line 3
#     numbers = [1, 2, 3, 4]
#     ^
# IndentationError: unexpected indent

# %%
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"
#parenthesis missing

# %%
#5.answer 
print("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0
#Error division by zero cant be done

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)
#error string and int cannot concatenate

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)
#step count is wrong

# %%
#8.correct code
for i in range(1,10,1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")
#for comaparing x value to 5 we should use ==

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)
    
#colon missing

# %%
#correct code
def greet(name):
    print("Hello, " + name)

# %%
greet("snega")
# Out:
# Hello, snega
# 'snega'
